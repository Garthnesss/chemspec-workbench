# %% [markdown]
# # Naphthalene UV-Vis walkthrough (≈5–10 min)
#
# A short **analysis-path** tour of ChemSpec / `spectrum_core` using a **real measured** UV-Vis spectrum from the [NIST Chemistry WebBook](https://webbook.nist.gov/chemistry/) (SRD 69).
#
# **What you will do**
#
# 1. Load `fixtures/public/naphthalene_uvvis_nist.jdx`
# 2. Note license / source (`SOURCES.md`) — NIST OSRD / INEP collection (not the PNNL “Owner: Public domain” IR set)
# 3. Plot the spectrum (matplotlib) — **y is log₁₀(ε) intensity, not absorbance**
# 4. Apply baseline (+ optional smooth)
# 5. Find peaks with **FWHM** and **area**
# 6. Optionally export a peaks CSV and mention session save
#
# **Setup** (repo root):
#
# ```bash
# pip install -e ".[dev,ui,baselines]"
# jupyter notebook examples/naphthalene_uvvis_walkthrough.ipynb
# # or: jupyter lab …
# ```
#
# Matplotlib only — **NiceGUI is not required**.
#
# ---
#
# ### Disclaimer — no compound identification
#
# ChemSpec Workbench and `spectrum_core` **do not identify compounds**.
# The fixture filename and NIST title say “Naphthalene” for **provenance only**. Peak centers, heights, FWHM, and area are **geometric metrics** on the loaded trace — not a library match or chemical ID claim.
#
# ### Y-axis honesty — log₁₀(ε), not absorbance
#
# JCAMP `##YUNITS=Logarithm epsilon` is **log₁₀ of molar absorptivity ε**. Ingest stores `y_unit=intensity` with a `unit_notes` entry. **Do not** treat plotted y as absorbance, and **do not** run **A ↔ %T** conversion on this trace without first converting from ε (requires path length and concentration — out of scope here).

# %% [markdown]
# ## 0 · Imports & locate the fixture

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

from spectrum_core import (
    apply_step,
    find_peaks,
    ingest,
    peaks_to_csv,
    save_session,
)

FIXTURE_REL = Path("fixtures") / "public" / "naphthalene_uvvis_nist.jdx"
SOURCES_REL = Path("fixtures") / "public" / "SOURCES.md"


def find_repo_root() -> Path:
    here = Path.cwd().resolve()
    for p in [here, *here.parents]:
        if (p / FIXTURE_REL).is_file():
            return p
    raise FileNotFoundError(
        f"Could not find {FIXTURE_REL}. Open the notebook from the "
        "chemspec-workbench repo (or set the working directory to the repo root)."
    )


ROOT = find_repo_root()
FIXTURE = ROOT / FIXTURE_REL
SOURCES = ROOT / SOURCES_REL
print("repo root:", ROOT)
print("fixture  :", FIXTURE)
print("sources  :", SOURCES if SOURCES.is_file() else "(missing)")

# %% [markdown]
# ## 1 · License / source (read this)
#
# The JCAMP is redistributed from the [NIST Chemistry WebBook](https://webbook.nist.gov/chemistry/) (SRD 69). File header quotes **OWNER=INEP CP RAS, NIST OSRD** and a U.S. Secretary of Commerce 2007 copyright notice — these are **not** the PNNL “Owner: Public domain” IR fixtures. ChemSpec redistributes them as educational / software fixtures with full attribution (MIT honesty on third-party terms).
#
# Full attribution, NIST disclaimer, download URLs, and the log₁₀(ε) → intensity mapping note live in:
#
# `fixtures/public/SOURCES.md`
#
# **Do not** treat the NIST compound title as a ChemSpec identification result.

# %%
# Peek at the UV-Vis section of the attribution file
text = SOURCES.read_text(encoding="utf-8")
marker = "## UV-Vis fixtures"
idx = text.find(marker)
snippet = text[idx : idx + 900] if idx >= 0 else text.split("---")[0]
print(snippet)
print("… see", SOURCES_REL.as_posix(), "for full tables and NIST disclaimer.")

# %% [markdown]
# ## 2 · Load the public naphthalene UV-Vis JCAMP
#
# `ingest()` dispatches `.jdx` / `.dx` to basic JCAMP-DX ingest (`jcamp`).
# `##XUNITS=Wavelength (nm)` → `x_unit=nm`; `##YUNITS=Logarithm epsilon` → `y_unit=intensity` with an explicit `unit_notes` entry (see `SOURCES.md`).

# %%
raw = ingest(FIXTURE)

print("title   :", raw.title, "  ← NIST label (provenance only)")
print("points  :", len(raw))
print("x_unit  :", raw.x_unit, "  y_unit:", raw.y_unit)
print("JCAMP YUNITS:", raw.meta.get("jcamp_yunits"))
for note in raw.meta.get("unit_notes") or []:
    print("unit_notes:", note)
print("x range :", float(np.nanmin(raw.x)), "…", float(np.nanmax(raw.x)), "nm")
print("y range :", float(np.nanmin(raw.y)), "…", float(np.nanmax(raw.y)), "(log₁₀ ε)")
print()
print("Reminder: y is NOT absorbance — skip A ↔ %T unless you convert from ε.")

# %% [markdown]
# ## 3 · Plot the raw spectrum
#
# UV-Vis wavelength (nm) is plotted **ascending** (unlike IR’s descending cm⁻¹ convention).

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(raw.x, raw.y, color="C0", lw=0.9)
ax.set_xlabel("Wavelength (nm)")
ax.set_ylabel("log₁₀(ε) intensity (as ingested — not absorbance)")
ax.set_title("Public naphthalene UV-Vis fixture — raw (not compound ID)")
ax.grid(True, alpha=0.3)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 4 · Baseline (+ optional smooth)
#
# Use the **processing pipeline** so steps are recorded in an append-only history (handy for session save later). Polynomial baseline always works without extras; optional `asls` / `mpls` need `pip install -e ".[baselines]"`.
#
# A light smooth is sensible on this digitized literature UV trace; treat baseline as optional continuum tidy-up on log₁₀(ε), not as an absorbance correction.

# %%
working, history = apply_step(
    raw, None, "baseline", {"method": "polynomial", "degree": 2}
)
working, history = apply_step(
    working, history, "smooth", {"window_length": 7, "polyorder": 2}
)

print("pipeline steps:")
for line in history.summary_lines():
    print(" ", line)

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(raw.x, raw.y, color="0.65", lw=0.8, label="raw")
ax.plot(working.x, working.y, color="C0", lw=1.2, label="baseline + smooth")
ax.set_xlabel("Wavelength (nm)")
ax.set_ylabel("log₁₀(ε) intensity (as ingested — not absorbance)")
ax.set_title("Baseline + Savitzky–Golay smooth")
ax.legend(loc="best")
ax.grid(True, alpha=0.3)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 5 · Find peaks (FWHM + area)
#
# `find_peaks` wraps `scipy.signal.find_peaks` and adds **FWHM** and **area** from prominence-relative half-max bounds (see `spectrum_core.peaks` docstring). These are **not** band assignments or compound ID.

# %%
PROMINENCE = 0.1  # vibronic structure after poly baseline (benzene twin); tweak as needed
peaks = find_peaks(working, prominence=PROMINENCE)
print(f"n_peaks = {len(peaks)}  (prominence={PROMINENCE})")
print()
print(f"{'idx':>6}  {'x':>10}  {'y':>12}  {'prominence':>12}  {'FWHM':>12}  {'area':>12}")
print("-" * 72)
for p in peaks:
    fwhm_s = f"{p.fwhm:12.4f}" if np.isfinite(p.fwhm) else f"{'nan':>12}"
    area_s = f"{p.area:12.4f}" if np.isfinite(p.area) else f"{'nan':>12}"
    print(
        f"{p.index:6d}  {p.x:10.1f}  {p.y:12.6g}  {p.prominence:12.6g}  "
        f"{fwhm_s}  {area_s}"
    )

# %%
fig, ax = plt.subplots(figsize=(10, 4.5))
ax.plot(working.x, working.y, color="C0", lw=1.1, label="processed")
if peaks:
    ax.scatter(
        [p.x for p in peaks],
        [p.y for p in peaks],
        color="C3",
        s=32,
        zorder=5,
        label=f"peaks (n={len(peaks)})",
    )
    for p in peaks[:8]:
        ax.annotate(
            f"{p.x:.0f}",
            (p.x, p.y),
            textcoords="offset points",
            xytext=(0, 8),
            ha="center",
            fontsize=8,
        )
ax.set_xlabel("Wavelength (nm)")
ax.set_ylabel("log₁₀(ε) intensity (as ingested — not absorbance)")
ax.set_title("Peaks with labels (wavelength only — not band ID)")
ax.legend(loc="best")
ax.grid(True, alpha=0.3)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 6 · Optional export — peaks CSV & session save
#
# - **`peaks_to_csv`** — peak table (`index`, `x`, `y`, `prominence`, `fwhm`, `area`)
# - **`save_session`** — analysis snapshot (`.csw.json`): embedded spectrum + pipeline history + peaks + notes
#
# Both are **analysis artifacts**, not identification reports. Session notes reiterate that y is log₁₀(ε), not absorbance.

# %%
# Write next to the notebook working directory (safe to delete)
OUT = Path("naphthalene_uvvis_walkthrough_out")
OUT.mkdir(exist_ok=True)

csv_path = OUT / "naphthalene_uvvis_peaks.csv"
peaks_to_csv(peaks, csv_path)
print("peaks CSV →", csv_path.resolve())
print(csv_path.read_text(encoding="utf-8").splitlines()[0])
print("…", len(peaks), "data rows")

session_path = OUT / "naphthalene_uvvis_walkthrough.csw.json"
save_session(
    session_path,
    raw,
    history=history,
    peaks=peaks,
    notes=(
        "Naphthalene UV-Vis tutorial walkthrough. "
        "Analysis snapshot — not compound identification. "
        "Y is log10(epsilon) intensity, not absorbance; do not run A↔%T "
        f"without converting from ε. Attribution: {SOURCES_REL.as_posix()}"
    ),
    source_path=str(FIXTURE),
    processing={
        "baseline_on": True,
        "baseline_method": "polynomial",
        "baseline_degree": 2,
        "prominence": PROMINENCE,
    },
)
print("session   →", session_path.resolve())

# %% [markdown]
# ## Done
#
# You exercised a real ChemSpec analysis path on a **public measured UV-Vis** fixture:
#
# | Step | API |
# |------|-----|
# | Load JCAMP | `ingest` / `ingest_jcamp` |
# | Baseline + smooth | `apply_step` (`baseline`, `smooth`) |
# | Peaks + FWHM/area | `find_peaks` |
# | Export | `peaks_to_csv`, `save_session` |
#
# **Still true:** ChemSpec does **not** identify naphthalene (or any compound). Y remains **log₁₀(ε) intensity**, not absorbance — skip A ↔ %T without converting from ε. For attribution see [`fixtures/public/SOURCES.md`](../fixtures/public/SOURCES.md).
#
# Script twin (headless / CI-friendly): `python examples/naphthalene_uvvis_walkthrough.py`
